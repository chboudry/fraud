# %% [markdown]
# ## Streamlit app — visual exploration
#
# `credit_fraud_app.py` lets you:
# - select a **credit application** (`Dossier`),
# - display its **community as it existed just before this application was added** (*"Hide the new application"* checkbox for the strictly prior state),
# - display the dossier's **properties** and its **evolution vector** (`IND_COM_*`).
#
# Remember to set the password/database at the top of `credit_fraud_app.py`. Run the next cell then open the displayed URL.

# %%
# Cell 10: Launch the Streamlit app (optional)

# !pip install streamlit streamlit-agraph -q
# !streamlit run credit_fraud_app.py --server.headless true
